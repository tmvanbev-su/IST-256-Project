# %%
## World Cup Bracket Builder
group_a = ['RUSSIA', 'EGYPT', 'SAUDI ARABIA', 'URUGUAY']
group_b = ['PORTUGAL', 'SPAIN', 'MOROCCO', 'IRAN']
group_c = ['FRANCE', 'AUSTRALIA', 'PERU', 'DENMARK']
group_d = ['ARGENTINA', 'ICELAND', 'CROATIA', 'NIGERIA']
group_e = ['BRAZIL', 'COSTA RICA', 'SWITZERLAND', 'SERBIA']
group_f = ['GERMANY', 'MEXICO', 'SWEDEN', 'SOUTH KOREA']
group_g = ['BELGIUM', 'PANAMA', 'TUNISIA', 'ENGLAND']
group_h = ['POLAND', 'COLOMBIA', 'SENEGAL', 'JAPAN']
 
 
print("Welcome to World Cup Bracket Picker 2018")
ready = input("Ready to get started? Type 'yes' to begin").upper()
while True:
    if ready == "YES":
        print("GROUP STAGE")
        print("Ok! Let's begin. For each group, select which team you think will come in 1st and then which team will come in 2nd.")
       
        def team_in_group_a(firstplacea, group_a):
            try:
                index = group_a.index(firstplacea)
                return True
            except ValueError:
                return False
 
        print("Group A:", (group_a))
 
        while True:
            firstplacea = input('First place: ').upper()
            if team_in_group_a(firstplacea, group_a):
                print("First place: %s " % (firstplacea))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplacea = input('Second place: ').upper()
            if team_in_group_a(secondplacea, group_a):
                print("Second place: %s " % (secondplacea))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_b(firstplaceb, group_b):
            try:
                index = group_b.index(firstplaceb)
                return True
            except ValueError:
                return False
 
        print("Group B:", (group_b))
 
        while True:
            firstplaceb = input('First place: ').upper()
            if team_in_group_b(firstplaceb, group_b):
                print("First place: %s " % (firstplaceb))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplaceb = input('Second place: ').upper()
            if team_in_group_b(secondplaceb, group_b):
                print("Second place: %s " % (secondplaceb))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_c(firstplacec, group_c):
            try:
                index = group_c.index(firstplacec)
                return True
            except ValueError:
                return False
 
        print("Group C:", (group_c))
 
        while True:
            firstplacec = input('First place: ').upper()
            if team_in_group_c(firstplacec, group_c):
                print("First place: %s " % (firstplacec))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplacec = input('Second place: ').upper()
            if team_in_group_c(secondplacec, group_c):
                print("Second place: %s " % (secondplacec))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_d(firstplaced, group_d):
            try:
                index = group_d.index(firstplaced)
                return True
            except ValueError:
                return False
 
        print("Group D:", (group_d))
 
        while True:
            firstplaced = input('First place: ').upper()
            if team_in_group_d(firstplaced, group_d):
                print("First place: %s " % (firstplaced))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplaced = input('Second place: ').upper()
            if team_in_group_d(secondplaced, group_d):
                print("Second place: %s " % (secondplaced))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_e(firstplacee, group_e):
            try:
                index = group_e.index(firstplacee)
                return True
            except ValueError:
                return False
 
        print("Group E:", (group_e))
 
        while True:
            firstplacee = input('First place: ').upper()
            if team_in_group_e(firstplacee, group_e):
                print("First place: %s " % (firstplacee))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplacee = input('Second place: ').upper()
            if team_in_group_e(secondplacee, group_e):
                print("Second place: %s " % (secondplacee))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_f(firstplacef, group_f):
            try:
                index = group_f.index(firstplacef)
                return True
            except ValueError:
                return False
 
        print("Group F:", (group_f))
 
        while True:
            firstplacef = input('First place: ').upper()
            if team_in_group_f(firstplacef, group_f):
                print("First place: %s " % (firstplacef))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplacef = input('Second place: ').upper()
            if team_in_group_f(secondplacef, group_f):
                print("Second place: %s " % (secondplacef))
                break
            else:
                print("Please enter a valid team!")
        def team_in_group_g(firstplaceg, group_g):
            try:
                index = group_g.index(firstplaceg)
                return True
            except ValueError:
                return False
 
        print("Group G:", (group_g))
 
        while True:
            firstplaceg = input('First place: ').upper()
            if team_in_group_g(firstplaceg, group_g):
                print("First place: %s " % (firstplaceg))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplaceg = input('Second place: ').upper()
            if team_in_group_g(secondplaceg, group_g):
                print("Second place: %s " % (secondplaceg))
                break
            else:
                print("Please enter a valid team!")
           
        def team_in_group_h(firstplaceh, group_h):
            try:
                index = group_h.index(firstplaceh)
                return True
            except ValueError:
                return False
 
        print("Group H:", (group_h))
 
        while True:
            firstplaceh = input('First place: ').upper()
            if team_in_group_h(firstplaceh, group_h):
                print("First place: %s " % (firstplaceh))
                break
            else:
                print("Please enter a valid team!")
 
        while True:
            secondplaceh = input('Second place: ').upper()
            if team_in_group_h(secondplaceh, group_h):
                print("Second place: %s " % (secondplaceh))
                break
            else:
                print("Please enter a valid team!")
           
        print("Group stage complete!")
        break
    else:
        print("Please enter 'yes' to begin!")
        ready = input("Ready to get started? Type 'yes' to begin").upper()
        continue
 
print("ROUND OF 16")  
 
matchup_a = [firstplacea, secondplaceb]
matchup_b = [firstplacec, secondplaced]
matchup_c = [firstplacee, secondplacef]
matchup_d = [firstplaceg, secondplaceh]
matchup_e = [firstplaceb, secondplacea]
matchup_f = [firstplaced, secondplacec]
matchup_g = [firstplacef, secondplacee]
matchup_h = [firstplaceh, secondplaceg]
 
 
def team_in_matchup_a(ros_one, matchup_a):
    try:
        index = matchup_a.index(ros_one)
        return True
    except ValueError:
        return False
 
while True:
    ros_one = input("Choose a winner: %s v. %s " % (firstplacea, secondplaceb)).upper()
    if team_in_matchup_a(ros_one, matchup_a):
        print("Winner: %s" % (ros_one))
        break
    else:
        print("Please enter a valid team!")
 
def team_in_matchup_b(ros_two, matchup_b):
    try:
        index = matchup_b.index(ros_two)
        return True
    except ValueError:
        return False
 
while True:
    ros_two = input("Choose a winner: %s v. %s " % (firstplacec, secondplaced)).upper()
    if team_in_matchup_b(ros_two, matchup_b):
        print("Winner: %s" % (ros_two))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_c(ros_three, matchup_c):
    try:
        index = matchup_c.index(ros_three)
        return True
    except ValueError:
        return False
 
while True:
    ros_three = input("Choose a winner: %s v. %s " % (firstplacee, secondplacef)).upper()
    if team_in_matchup_c(ros_three, matchup_c):
        print("Winner: %s" % (ros_three))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_d(ros_four, matchup_d):
    try:
        index = matchup_d.index(ros_four)
        return True
    except ValueError:
        return False
 
while True:
    ros_four = input("Choose a winner: %s v. %s " % (firstplaceg, secondplaceh)).upper()
    if team_in_matchup_d(ros_four, matchup_d):
        print("Winner: %s" % (ros_four))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_e(ros_five, matchup_e):
    try:
        index = matchup_e.index(ros_five)
        return True
    except ValueError:
        return False
 
while True:
    ros_five = input("Choose a winner: %s v. %s " % (firstplaceb, secondplacea)).upper()
    if team_in_matchup_e(ros_five, matchup_e):
        print("Winner: %s" % (ros_five))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_f(ros_six, matchup_f):
    try:
        index = matchup_f.index(ros_six)
        return True
    except ValueError:
        return False
 
while True:
    ros_six = input("Choose a winner: %s v. %s " % (firstplaced, secondplacec)).upper()
    if team_in_matchup_f(ros_six, matchup_f):
        print("Winner: %s" % (ros_six))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_g(ros_seven, matchup_g):
    try:
        index = matchup_g.index(ros_seven)
        return True
    except ValueError:
        return False
 
while True:
    ros_seven = input("Choose a winner: %s v. %s " % (firstplacef, secondplacee)).upper()
    if team_in_matchup_g(ros_seven, matchup_g):
        print("Winner: %s" % (ros_seven))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_h(ros_eight, matchup_h):
    try:
        index = matchup_h.index(ros_eight)
        return True
    except ValueError:
        return False
 
while True:
    ros_eight = input("Choose a winner: %s v. %s " % (firstplaceh, secondplaceg)).upper()
    if team_in_matchup_h(ros_eight, matchup_h):
        print("Winner: %s" % (ros_eight))
        break
    else:
        print("Please enter a valid team!")
       
print("Round of 16 complete!")
       
matchup_i = [ros_one, ros_two]
matchup_j = [ros_three, ros_four]
matchup_k = [ros_five, ros_six]
matchup_l = [ros_seven, ros_eight]
 
print("QUARTERFINALS")
 
def team_in_matchup_i(qf_one, matchup_i):
    try:
        index = matchup_i.index(qf_one)
        return True
    except ValueError:
        return False
 
while True:
    qf_one = input("Choose a winner: %s v. %s " % (ros_one, ros_two)).upper()
    if team_in_matchup_i(qf_one, matchup_i):
        print("Winner: %s" % (qf_one))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_j(qf_two, matchup_j):
    try:
        index = matchup_j.index(qf_two)
        return True
    except ValueError:
        return False
 
while True:
    qf_two = input("Choose a winner: %s v. %s " % (ros_three, ros_four)).upper()
    if team_in_matchup_j(qf_two, matchup_j):
        print("Winner: %s" % (qf_two))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_k(qf_three, matchup_k):
    try:
        index = matchup_k.index(qf_three)
        return True
    except ValueError:
        return False
   
while True:
    qf_three = input("Choose a winner: %s v. %s " % (ros_five, ros_six)).upper()
    if team_in_matchup_k(qf_three, matchup_k):
        print("Winner: %s" % (qf_three))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_l(qf_four, matchup_l):
    try:
        index = matchup_l.index(qf_four)
        return True
    except ValueError:
        return False
   
while True:
    qf_four = input("Choose a winner: %s v. %s " % (ros_seven, ros_eight)).upper()
    if team_in_matchup_l(qf_four, matchup_l):
        print("Winner: %s" % (qf_four))
        break
    else:
        print("Please enter a valid team!")
 
print("Quarterfinals complete!")
 
matchup_m = [qf_one, qf_two]
matchup_n = [qf_three, qf_four]
 
print("SEMIFINALS")
 
def team_in_matchup_m(semi_one, matchup_m):
    try:
        index = matchup_m.index(semi_one)
        return True
    except ValueError:
        return False
   
while True:
    semi_one = input("Choose a winner: %s v. %s " % (qf_one, qf_two)).upper()
    if team_in_matchup_m(semi_one, matchup_m):
        print("Winner: %s" % (semi_one))
        break
    else:
        print("Please enter a valid team!")
       
def team_in_matchup_n(semi_two, matchup_n):
    try:
        index = matchup_n.index(semi_two)
        return True
    except ValueError:
        return False
   
while True:
    semi_two = input("Choose a winner: %s v. %s " % (qf_three, qf_four)).upper()
    if team_in_matchup_n(semi_two, matchup_n):
        print("Winner: %s" % (semi_two))
        break
    else:
        print("Please enter a valid team!")
 
 
print("Semifinals complete!")
 
matchup_o = [semi_one, semi_two]
 
print("FINAL")
 
def team_in_matchup_o(final, matchup_o):
    try:
        index = matchup_o.index(final)
        return True
    except ValueError:
        return False
   
while True:
    final = input("Who will take home the trophy: %s or %s? " % (semi_one, semi_two)).upper()
    if team_in_matchup_o(final, matchup_o):
        print("You chose %s as your champion!" % (final))
        break
    else:
        print("You should have learned this by now. Please enter a valid champion!")
print("Thank you for playing World Cup Bracket Picker 2018!")

# %%
## World Cup Quiz
print("Welcome to the World Cup quiz to help you determine what team matches the most with what you want out of a soccer match")

#Question 1
question1 = "Do you like teams that score a lot?"
options1 = "A. yes\nB. no\n"
print(question1)
print(options1)
while True:
    response = input("Enter in a letter for your answer\n")
    if response == "a": 
        response = response.upper()
        print(response)
        break
    if response == "b":
        response = response.upper()
        print(response)
        break 
    else:
        print("Incorrect!!! Try again.")
            
#Question 2
question2 = "Do you want an underdog or favorited team to win?"
options2 = "A. favorite\nB. underdog\n"
print(question2)
print(options2)

while True:
    response = input("Enter in a letter for your answer\n")
    if response == "a":
        response = response.upper()
        print(response)
        break
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")
        
#Question 3
question3 = "Do you like a rowdy fan base?"
options3 = "A. yes\nB. no\n"
print(question3)
print(options3)

while True:
    response = input("Enter in a letter for your answer\n")

    if response == "a":
        response = response.upper()
        print(response)
        break
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")
            
#Question 4 
question4 = "How important is it that you have major stars to root for?"
options4 = "A. I love Messi and Ranoldo\nB. Who's Lionel Messi\n"
print(question4)
print(options4)

while True:
    response = input("Enter in a letter for your answer\n")
    
    if response == "a":
        response = response.upper()
        print(response)
        break 
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")

#Question 5
question5 = "I love a team that ... ?"
options5 = "A. plays fundemental soccer\nB. is flashey\n"
print(question5)
print(options5)

while True:
    response = input("Enter in a letter for your answer\n")

    if response == "a": 
        response = response.upper()
        print(response)
        break
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")

#Question 6
question6 = "How badly do you want to say your team won?"
options6 = "A. I'm from Cleveland I need a win\nB. roll the dice I'm not worried\n"
print(question6)
print(options6)

while True:
    response = input("Enter in a letter for your answer\n") 

    if response == "a":
        response = response.upper()
        print(response)
        break 
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")

#Question 7        
question7 = "Football or Fútbol?"
options7 = "A. Football\nB. Soccer\n"
print(question7)
print(options7)

while True:
    response = input("Enter in a letter for your answer\n")

    if response == "a":
        response = response.upper()
        print(response)
        break
    if response == "b":
        response = response.upper()
        print(response)
        break
    else:
        print("Incorrect!!! Try again.")
        
import random
Team_List=['CONGRATS with being selected with Egypt they are lead by top tier forward Mohamed Salah. Good Luck. ','CONGRATS with being select with Russia they host the world cup this year hopefully home field advantage can help them out.', 'CONGRATS with being selected with Saudi Arabia. They are a big underdog this year, but its not called a cinderella story for nothing.', 'CONGRATS with being selected with Uruguay they can do damage this year and bring the world cup trophy back to South America', 'CONGRATS with being selected with Iran a team that continues to perform year in and out. ', 'CONGRATS with being selected with Morocco one of the few African nations that might have what it takes to bring home a trophy.', 'CONGRATS with being selected with Portugal, take a seat and learn why they call it the beautiful game. ', 'CONGRATS with being selected with Spain a formidable team that led by a star studded roster. ', 'CONGRATS with being selected with Australia even though they don’t have much history with making a dent in the World Cup 2018 could be the year the trophy heads to the big under.', 'CONGRATS  with being selected with Denmark they may have just slipped into the tournament but it’s all about taking it one game at a time. ', 'CONGRATS with being selected with France a powerhouse of football that are led by a young footballer, Antoine Griezmann. ', 'CONGRATS with being selected with Peru a tough South American team that is willing to play all 90 minutes no matter the opponent. ', 'CONGRATS with being selected with Argentina who are lead by Lionel Messi, ever heard of him. ','CONGRATS  with being selected with Croatia, no body may want it more than these guys. ', 'CONGRATS on being selected with Iceland, you only need to know one word SKOL!!! ', 'CONGRATS on being selected with Nigeria a team that needs to perform on the international stage to prove they know what football is all about. ', 'CONGRATS on being selected with Brazil a team that is led by Neymar who might just be one of the best young players to play, EVER. ',' CONGRATS on being selected with Costa Rica who are led by captain Bryan Ruiz hopefully the veteran can bring his team to glory. ', 'CONGRATS on being selected with Switzerland. No body knows for sure if they can win it this year, but that’s the beauty of the game. ', 'CONGRATS on being selected with Serbia who are captained by the AC Roma left back,  Aleksandar Kolarov. ', 'CONGRATS on being selected with Germany, this team is full of entertaining players such as Mesut Ozil, Thomas Muller, Marco Rues and more. Enjoy. ' ,'CONGRATS on being selected with South Korea. Don’t underestimate them they can make a pretty big dent if they really want to. ', 'CONGRATS on being selected with Mexico, since the US isn’t in the World Cup you should cheer on our good neighbor. ', 'CONGRATS on being selected with Sweden a team that even the analysts have no idea what they’re capable of, does that mean last one standing or heart break first loss. ', 'CONGRATS on being selected with Belgium a team that is playing the game well currently, they are led by Kevin de Bruyne so keep a watchful eye on them. ', 'CONGRATS on being selected with England a team that plays the game with an edge as England is the home of football. ', 'CONGRATS on being selected with Panama. This Central American team isn’t expected to do much but did that ever stop teams in the past from busting up the tournament. ', 'CONGRATS on being selected with Tun
Spanish_speaking=['CONGRATS on being selected with Brazil a team that is led by Neymar who might just be one of the best young players to play, EVER. ','CONGRATS with being selected with Portugal, take a seat and learn why they call it the beautiful game.', 'CONGRATS with being selected with Argentina who are lead by Lionel Messi, ever heard of him. ', 'CONGRATS with being selected with Spain a formidable team that led by a star studded roster. ',' CONGRATS with being selected with Peru a tough South American team that is willing to play all 90 minutes no matter the opponent. ', ' CONGRATS on being selected with Colombia a country that only knows football. Enjoy. ', 'CONGRATS on being selected with Mexico, since the US isn’t in the World Cup you should cheer on our good neighbor. ',' CONGRATS with being selected with Uruguay they can do damage this year and bring the world cup trophy back to South America. ',' CONGRATS on being selected with Costa Rica who are led by captain Bryan Ruiz hopefully the veteran can bring his team to glory. ',' CONGRATS on being selected with Panama. This Central American team isn’t expected to do much but did that ever stop teams in the past from busting up the tournament. ']

score_a=int(input("Please enter how many questions you answered with a: "))
score_b=int(input("Please enter how many questions you answered with b: "))
if score_a+score_b > 7 or score_a+score_b < 7:
    print("Please enter a the correct number of times you entered a and b") 
elif score_a == 0 and score_7 == 7:
    print(random.choice(fundemental))
elif score_a == 1 and score_b == 6:
    print(random.choice(Spanish_speaking))
elif score_a == 2 and score_b == 5:
    print(random.choice(flashy))
elif score_a == 3 and score_b == 4:
    print(random.choice(rowdy_fans))
elif score_a == 4 and score_b == 3:
    print(random.choice(underdog_team))
elif score_a == 5 and score_b == 2:
    print(random.choice(favorites))
elif score_a == 6 and score_b == 1:
    print(random.choice(star_power))
elif score_a == 7 and score_b == 0:
    print(random.choice(high_score))
# Out:
# Welcome to the World Cup quiz to help you determine what team matches the most with what you want out of a soccer match
# Do you like teams that score a lot?
# A. yes
# B. no
#
# Enter in a letter for your answer
# b
# B
# Do you want an underdog or favorited team to win?
# A. favorite
# B. underdog
#
# Enter in a letter for your answer
# a
# A
# Do you like a rowdy fan base?
# A. yes
# B. no
#
# Enter in a letter for your answer
# a
# A
# How important is it that you have major stars to root for?
# A. I love Messi and Ranoldo
# B. Who's Lionel Messi
#
# Enter in a letter for your answer
# a
# A
# I love a team that ... ?
# A. plays fundemental soccer
# B. is flashey
#
# Enter in a letter for your answer
# a
# A
# How badly do you want to say your team won?
# A. I'm from Cleveland I need a win
# B. roll the dice I'm not worried
#
# Enter in a letter for your answer
# a
# A
# Football or Fútbol?
# A. Football
# B. Soccer
#
# Enter in a letter for your answer
# a
# A
# ...

# %%
## World Cup Champion Likelihood Calculator 
import pandas as pd
import numpy as np

import warnings 
warnings.filterwarnings('ignore')

standings_df = pd.read_csv("ALL Quals")
standings_df

standings_df['World Cup Champion Percentage'] = standings_df['GF'] / standings_df['GF']+ standings_df['GA']
standings_df

print("Welcome to the World Cup 2018 Champion Percentage Calculator!")
team_name = input("Please enter your favorite team to see their chances of winning it all this year!!! ").upper()

winner_df = standings_df[['Team','World Cup Champion Percentage']][standings_df['Team'] == team_name]
winner_df
# Out:
# Welcome to the World Cup 2018 Champion Percentage Calculator!
# Please enter your favorite team to see their chances of winning it all this year!!! argentina
#          Team  World Cup Champion Percentage
# 15  ARGENTINA                           17.0
